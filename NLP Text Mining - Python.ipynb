# %% [markdown]
# ###### Any Voice Assistant or program understands our commands because of NLP

# %% [markdown]
# ###### What is Text mining and use of NLP for Text Mining

# %% [markdown]
# ###### NLP is a sub-field of AI which teaches computers to understand & interpret human spoken language or natural language

# %% [markdown]
# ###### Text Mining - Process of exploring & analysing large collection of unstructured textual data & deriving useful information, pattern & actionable insights from it.

# %% [markdown]
# ![Text_Mining_Use.jpg](attachment:Text_Mining_Use.jpg)

# %% [markdown]
# ![Text_Mining_Categories%20-%20Copy.jpg](attachment:Text_Mining_Categories%20-%20Copy.jpg)
